# %%
import sympy as sp
import numpy as np

from Cluster import Cluster
from FusionGate import FusionGate
from photonic_circuit import PhotonicCircuit
from main import runOverPMCombinations, best_combo_with_vs_without_rotation

# %%
print("Init Fusion Gates...")
# a
error_angle = 0.1
error_axis = [0, 1, 0]
fm = FusionGate(error_angle=-error_angle, error_axis=error_axis)
fp = FusionGate(error_angle=error_angle, error_axis=error_axis)
fi = FusionGate(error_angle=0, error_axis=error_axis)
print("Done!")
# Out:
# Init Fusion Gates...
# Done!

# %%
# Like
# Batch - Cluster(2) Clicks 00/11
runOverPMCombinations(fi, fp, fm, cluster_size=2, clicks='00', fusions_amount=3, rot_state_angle=0, rot_state_axis=[1,0,0])
runOverPMCombinations(fi, fp, fm, cluster_size=2, clicks='00', fusions_amount=6, rot_state_angle=0, rot_state_axis=[1,0,0])
runOverPMCombinations(fi, fp, fm, cluster_size=2, clicks='00', fusions_amount=8, rot_state_angle=0, rot_state_axis=[1,0,0])
runOverPMCombinations(fi, fp, fm, cluster_size=2, clicks='11', fusions_amount=8, rot_state_angle=0, rot_state_axis=[1,0,0])
# Out:
# ---------------------------------------
# Finding combination for  4 cluster of 2   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.2192847441156359+0j)
# Worst case is : 000 value: (0.2192847441156359+0j)
# Best case is : 010 value: (0.09335223976022729+0j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  7 cluster of 2   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.1498111224314413+0j)
# Worst case is : 000000 value: (0.1498111224314413+0j)
# Best case is : 011100 value: (0.030586116481532484+0j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  9 cluster of 2   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.09798580969836924+0j)
# Worst case is : 00000000 value: (0.09798580969836924+0j)
# Best case is : 01000111 value: (0.01763678931147022+0j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  9 cluster of 2   Clicks are  11
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.09798580969836937+0j)
# Worst case is : 00000000 value: (0.09798580969836937+0j)
# Best case is : 01000111 value: (0.01763678931147022+0j)
# ---------------------------------------

# %%
# Batch - Cluster(2) Clicks 10
runOverPMCombinations(fi, fp, fm, cluster_size=2, clicks='10', fusions_amount=8)
runOverPMCombinations(fi, fp, fm, cluster_size=2, clicks='10', fusions_amount=5)
runOverPMCombinations(fi, fp, fm, cluster_size=2, clicks='10', fusions_amount=3)

# Batch - Cluster(2) Clicks 01 odd
runOverPMCombinations(fi, fp, fm, cluster_size=2, clicks='01', fusions_amount=3)
runOverPMCombinations(fi, fp, fm, cluster_size=2, clicks='01', fusions_amount=5)

# Batch - Cluster(2) Clicks 01 Even
runOverPMCombinations(fi, fp, fm, cluster_size=2, clicks='01', fusions_amount=4)
runOverPMCombinations(fi, fp, fm, cluster_size=2, clicks='01', fusions_amount=6)
# Out:
# ---------------------------------------
# Finding combination for  9 cluster of 2   Clicks are  10
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.0025135216825180823+0j)
# Worst case is : 00000000 value: (0.0025135216825180823+0j)
# Best case is : 10110100 value: (0.002511985682512207+0j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  6 cluster of 2   Clicks are  10
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.002536577540637233+0j)
# Worst case is : 11000 value: (0.0025370354440505025+0j)
# Best case is : 00000 value: (0.002536577540637233+0j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  4 cluster of 2   Clicks are  10
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.002536951292239411+0j)
# Worst case is : 110 value: (0.002536976220313466+0j)
# Best case is : 000 value: (0.002536951292239411+0j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  4 cluster of 2   Clicks are  01
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.002536951292238969-6.938893903907228e-18j)
# Worst case is : 111 value: (0.0025369762203130246+1.3877787807814457e-17j)
# Best case is : 000 value: (0.002536951292238969-6.938893903907228e-18j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  6 cluster of 2   Clicks are  01
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.0025365775406367913-6.938893903907228e-18j)
# Worst case is : 11001 value: (0.0025370354440513955+1.3877787807814457e-17j)
# Best case is : 00000 value: (0.0025365775406367913-6.938893903907228e-18j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  5 cluster of 2   Clicks are  01
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.0025121990335774946-6.938893903907228e-18j)
# Worst case is : 0001 value: (0.0025121990335774946+6.938893903907228e-18j)
# Best case is : 1100 value: (0.002512012697369836-6.938893903907228e-18j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  7 cluster of 2   Clicks are  01
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.002512719120838119-6.938893903907228e-18j)
# Worst case is : 000001 value: (0.002512719120838119+6.938893903907228e-18j)
# Best case is : 001110 value: (0.002511967266878624-6.938893903907228e-18j)
# ---------------------------------------

# %%
# Batch - Cluster(3) Clicks 00 Even/Odd
runOverPMCombinations(fi, fp, fm, cluster_size=3, clicks='00', fusions_amount=2)
runOverPMCombinations(fi, fp, fm, cluster_size=3, clicks='00', fusions_amount=3)
runOverPMCombinations(fi, fp, fm, cluster_size=3, clicks='00', fusions_amount=4)
# runOverPMCombinations(fi, fp, fm, cluster_size=3, clicks='00', fusions_amount=5)
#
# # Batch - Cluster(3) Clicks 11 Even/Odd
# runOverPMCombinations(fi, fp, fm, cluster_size=3, clicks='11', fusions_amount=4)
#
# # Batch - Cluster(3) Clicks 01 Even/Odd (no big gap)
# runOverPMCombinations(fi, fp, fm, cluster_size=3, clicks='01', fusions_amount=5)
# Out:
# ---------------------------------------
# Finding combination for  3 cluster of 3   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.5978790259738338+0j)
# Worst case is : 00 value: (0.5978790259738338+0j)
# Best case is : 01 value: (0.20028961644976076+0j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  4 cluster of 3   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.8771389764625436+2.2762136403133863e-18j)
# Worst case is : 000 value: (0.8771389764625436+2.2762136403133863e-18j)
# Best case is : 001 value: (0.37340895904090915-4.0277910090815152e-19j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  5 cluster of 3   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (1.1534653407736715-1.5934236305062025e-18j)
# Worst case is : 1111 value: (1.1534653407736715+1.5934236305062025e-18j)
# Best case is : 0110 value: (0.28289699511966976-1.2622737457884652e-19j)
# ---------------------------------------

# %%
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=2, clicks='00', fusions_amount=3, rot_state_angle=0.2,
                      rot_state_axis=[1, 0, 0])
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=2, clicks='00', fusions_amount=6, rot_state_angle=0.2,
                      rot_state_axis=[1, 0, 0])
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=2, clicks='00', fusions_amount=8, rot_state_angle=0.2,
                      rot_state_axis=[1, 0, 0])
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=2, clicks='11', fusions_amount=8, rot_state_angle=0.2,
                      rot_state_axis=[1, 0, 0])

# Conclusion - No Effect of X rotation at all
# Out:
# ---------------------------------------
# Finding combination for  4 cluster of 2   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.00891514195873273
# Worst case is : 101 value: 0.010890781106796745
# Best case is : 001 value: 5.106869576235327e-05
# ---------------------------------------
# ---------------------------------------
# Finding combination for  4 cluster of 2   Clicks are  00
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.008915141958732367
# Worst case is : 101 value: 0.01089078110679639
# Best case is : 001 value: 5.10686957619922e-05
# ---------------------------------------
# ---------------------------------------
# Finding combination for  7 cluster of 2   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.025014206061478708
# Worst case is : 111111 value: 0.03362576430991411
# Best case is : 100100 value: 0.00034561759007081805
# ---------------------------------------
# ---------------------------------------
# Finding combination for  7 cluster of 2   Clicks are  00
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.02501420606147864
# Worst case is : 111111 value: 0.033625764309914125
# Best case is : 001001 value: 0.00034561759007080417
# ---------------------------------------
# ---------------------------------------
# Finding combination for  9 cluster of 2   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.04079667201149219
# Worst case is : 11111111 value: 0.05569361855389132
# Best case is : 11000001 value: 0.0002068404392380624
# ---------------------------------------
# ---------------------------------------
# Finding combination for  9 cluster of 2   Clicks are  00
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.04079667201149212
# Worst case is : 11111111 value: 0.05569361855389125
# Best case is : 11000001 value: 0.0002068404392380624
# ---------------------------------------
# ---------------------------------------
# Finding combination for  9 cluster of 2   Clicks are  11
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.040796672011492105
# Worst case is : 11111111 value: 0.055693618553891294
# Best case is : 10000011 value: 0.00020684043923800688
# ---------------------------------------
# ---------------------------------------
# Finding combination for  9 cluster of 2   Clicks are  11
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.040796672011491966
# Worst case is : 11111111 value: 0.05569361855389125
# Best case is : 10000011 value: 0.00020684043923789586
# ---------------------------------------

# %%
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=2, clicks='00', fusions_amount=3, rot_state_angle=0.2,
                      rot_state_axis=[0, 0, 1])
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=2, clicks='00', fusions_amount=6, rot_state_angle=0.2,
                      rot_state_axis=[0, 0, 1])
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=2, clicks='00', fusions_amount=8, rot_state_angle=0.2,
                      rot_state_axis=[0, 0, 1])
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=2, clicks='11', fusions_amount=8, rot_state_angle=0.2,
                      rot_state_axis=[0, 0, 1])

# Conclusion - Z Effect of  rotation at all - optimal is depend on state
# Out:
# ---------------------------------------
# Finding combination for  4 cluster of 2   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.00891514195873273
# Worst case is : 101 value: 0.010890781106796745
# Best case is : 001 value: 5.106869576235327e-05
# ---------------------------------------
# ---------------------------------------
# Finding combination for  4 cluster of 2   Clicks are  00
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.009915688144336571
# Worst case is : 101 value: 0.03127099984057362
# Best case is : 011 value: 0.0009859866777400888
# ---------------------------------------
# ---------------------------------------
# Finding combination for  7 cluster of 2   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.025014206061478708
# Worst case is : 111111 value: 0.03362576430991411
# Best case is : 100100 value: 0.00034561759007081805
# ---------------------------------------
# ---------------------------------------
# Finding combination for  7 cluster of 2   Clicks are  00
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.0013352282832128082
# Worst case is : 111111 value: 0.06420100824300222
# Best case is : 000100 value: 0.0003346671145565
# ---------------------------------------
# ---------------------------------------
# Finding combination for  9 cluster of 2   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.04079667201149219
# Worst case is : 11111111 value: 0.05569361855389132
# Best case is : 11000001 value: 0.0002068404392380624
# ---------------------------------------
# ---------------------------------------
# Finding combination for  9 cluster of 2   Clicks are  00
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.006252079672397146
# Worst case is : 11111111 value: 0.09496115953015749
# Best case is : 01011000 value: 0.00019935410353671967
# ---------------------------------------
# ---------------------------------------
# Finding combination for  9 cluster of 2   Clicks are  11
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.040796672011492105
# Worst case is : 11111111 value: 0.055693618553891294
# Best case is : 10000011 value: 0.00020684043923800688
# ---------------------------------------
# ---------------------------------------
# Finding combination for  9 cluster of 2   Clicks are  11
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.0737148297788319
# Worst case is : 01010101 value: 0.08762902836201929
# Best case is : 01010010 value: 0.00029308826370390284
# ---------------------------------------

# %%
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=3, clicks='00', fusions_amount=4, rot_state_angle=0.2,
                      rot_state_axis=[0, 0, 1])
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=3, clicks='00', fusions_amount=5, rot_state_angle=0.2,
                      rot_state_axis=[0, 0, 1])
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=3, clicks='00', fusions_amount=6, rot_state_angle=0.2,
                      rot_state_axis=[0, 0, 1])
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=3, clicks='00', fusions_amount=7, rot_state_angle=0.2,
                      rot_state_axis=[0, 0, 1])
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=3, clicks='01', fusions_amount=5, rot_state_angle=0.2,
                      rot_state_axis=[0, 0, 1])
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=3, clicks='11', fusions_amount=4, rot_state_angle=0.2,
                      rot_state_axis=[0, 0, 1])
# Out:
# ---------------------------------------
# Finding combination for  5 cluster of 3   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.009904873126823076
# Worst case is : 0000 value: 0.009904873126823076
# Best case is : 1010 value: 0.009904383015761343
# ---------------------------------------
# ---------------------------------------
# Finding combination for  5 cluster of 3   Clicks are  00
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.009904873126823076
# Worst case is : 0000 value: 0.009904873126823076
# Best case is : 1010 value: 0.009904383015761402
# ---------------------------------------
# ---------------------------------------
# Finding combination for  6 cluster of 3   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.012365694116318241
# Worst case is : 11111 value: 0.01236569411631832
# Best case is : 10101 value: 0.012364961384326602
# ---------------------------------------
# ---------------------------------------
# Finding combination for  6 cluster of 3   Clicks are  00
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.012365694116318047
# Worst case is : 11111 value: 0.012365694116318458
# Best case is : 01010 value: 0.0123649613843266
# ---------------------------------------
# ---------------------------------------
# Finding combination for  7 cluster of 3   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.01482045879062235
# Worst case is : 000000 value: 0.01482045879062235
# Best case is : 010101 value: 0.014819364836276716
# ---------------------------------------
# ---------------------------------------
# Finding combination for  7 cluster of 3   Clicks are  00
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.014820458790622517
# Worst case is : 000000 value: 0.014820458790622517
# Best case is : 010101 value: 0.014819364836276768
# ---------------------------------------
# ---------------------------------------
# Finding combination for  8 cluster of 3   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.017269062689102468
# Worst case is : 1111111 value: 0.01726906268910331
# Best case is : 0101010 value: 0.017267609312216096
# ---------------------------------------
# ---------------------------------------
# Finding combination for  8 cluster of 3   Clicks are  00
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.017269062689102496
# Worst case is : 1111111 value: 0.01726906268910304
# Best case is : 0101010 value: 0.01726760931221612
# ---------------------------------------
# ---------------------------------------
# Finding combination for  6 cluster of 3   Clicks are  01
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.012364961384327345
# Worst case is : 10101 value: 0.012365694116318434
# Best case is : 11111 value: 0.01236496138432688
# ---------------------------------------
# ---------------------------------------
# Finding combination for  6 cluster of 3   Clicks are  01
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.01236496138432715
# Worst case is : 01010 value: 0.012365694116318326
# Best case is : 11111 value: 0.01236496138432685
# ---------------------------------------
# ---------------------------------------
# Finding combination for  5 cluster of 3   Clicks are  11
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.009904873126822991
# Worst case is : 0000 value: 0.009904873126822991
# Best case is : 0101 value: 0.009904383015761482
# ---------------------------------------
# ---------------------------------------
# Finding combination for  5 cluster of 3   Clicks are  11
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.00990487312682302
# Worst case is : 1111 value: 0.009904873126823071
# Best case is : 0101 value: 0.0099043830157614
# ---------------------------------------

# %%
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=3, clicks='00', fusions_amount=4, rot_state_angle=0.2,
                      rot_state_axis=[1, 0, 0])
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=3, clicks='00', fusions_amount=5, rot_state_angle=0.2,
                      rot_state_axis=[1, 0, 0])
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=3, clicks='00', fusions_amount=6, rot_state_angle=0.2,
                      rot_state_axis=[1, 0, 0])
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=3, clicks='00', fusions_amount=7, rot_state_angle=0.2,
                      rot_state_axis=[1, 0, 0])
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=3, clicks='01', fusions_amount=5, rot_state_angle=0.2,
                      rot_state_axis=[1, 0, 0])
best_combo_with_vs_without_rotation(fi, fp, fm, cluster_size=3, clicks='11', fusions_amount=4, rot_state_angle=0.2,
                      rot_state_axis=[1, 0, 0])
# Out:
# ---------------------------------------
# Finding combination for  5 cluster of 3   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.009904873126823076
# Worst case is : 0000 value: 0.009904873126823076
# Best case is : 1010 value: 0.009904383015761343
# ---------------------------------------
# ---------------------------------------
# Finding combination for  5 cluster of 3   Clicks are  00
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.013642695513988997
# Worst case is : 1111 value: 0.013642695513989257
# Best case is : 0101 value: 0.013642332240146209
# ---------------------------------------
# ---------------------------------------
# Finding combination for  6 cluster of 3   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.012365694116318241
# Worst case is : 11111 value: 0.01236569411631832
# Best case is : 10101 value: 0.012364961384326602
# ---------------------------------------
# ---------------------------------------
# Finding combination for  6 cluster of 3   Clicks are  00
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.015952269656962816
# Worst case is : 00000 value: 0.015952269656962816
# Best case is : 10101 value: 0.01595154328305417
# ---------------------------------------
# ---------------------------------------
# Finding combination for  7 cluster of 3   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.01482045879062235
# Worst case is : 000000 value: 0.01482045879062235
# Best case is : 010101 value: 0.014819364836276716
# ---------------------------------------
# ---------------------------------------
# Finding combination for  7 cluster of 3   Clicks are  00
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.01838573377097428
# Worst case is : 111111 value: 0.018385733770975445
# Best case is : 010101 value: 0.01838464930912566
# ---------------------------------------
# ---------------------------------------
# Finding combination for  8 cluster of 3   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.017269062689102468
# Worst case is : 1111111 value: 0.01726906268910331
# Best case is : 0101010 value: 0.017267609312216096
# ---------------------------------------
# ---------------------------------------
# Finding combination for  8 cluster of 3   Clicks are  00
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.02081309056764131
# Worst case is : 1111111 value: 0.020813090567641968
# Best case is : 1010101 value: 0.020811649802040654
# ---------------------------------------
# ---------------------------------------
# Finding combination for  6 cluster of 3   Clicks are  01
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.012364961384327345
# Worst case is : 10101 value: 0.012365694116318434
# Best case is : 11111 value: 0.01236496138432688
# ---------------------------------------
# ---------------------------------------
# Finding combination for  6 cluster of 3   Clicks are  01
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.01595154328305417
# Worst case is : 10101 value: 0.015952269656962753
# Best case is : 11111 value: 0.015951543283054016
# ---------------------------------------
# ---------------------------------------
# Finding combination for  5 cluster of 3   Clicks are  11
# State change from cluster is theta= 0
# Statrting...
# Naive dist from ideal : 0.009904873126822991
# Worst case is : 0000 value: 0.009904873126822991
# Best case is : 0101 value: 0.009904383015761482
# ---------------------------------------
# ---------------------------------------
# Finding combination for  5 cluster of 3   Clicks are  11
# State change from cluster is theta= 0.2
# Statrting...
# Naive dist from ideal : 0.013642695513989118
# Worst case is : 0000 value: 0.013642695513989118
# Best case is : 1010 value: 0.013642332240146098
# ---------------------------------------

# %%
runOverPMCombinations(fi, fp, fm, cluster_size=[2,3,4], clicks='00', fusions_amount=2)
runOverPMCombinations(fi, fp, fm, cluster_size=[5,3,2], clicks='00', fusions_amount=2)
# Out:
# ---------------------------------------
# Finding combination for  3 cluster of [2, 3, 4]   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.5978790259738338+0j)
# Worst case is : 00 value: (0.5978790259738338+0j)
# Best case is : 01 value: (0.20028961644976076+0j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  3 cluster of [5, 3, 2]   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.8455286271906116+7.662660481530548e-19j)
# Worst case is : 00 value: (0.8455286271906116+7.662660481530548e-19j)
# Best case is : 01 value: (0.28325229198575697-3.1579543911147417e-19j)
# ---------------------------------------

# %%
# Function of size?
for i in range(1,10,1):
    runOverPMCombinations(fi, fp, fm, cluster_size=2, clicks='00', fusions_amount=i)
# Out:
# Naive (00..0) dist from ideal : (0.01763678931147019+0j)
# Worst case is : 01100111 value: (0.017636789311470225+0j)
# Best case is : 00001101 value: (0.017636789311470186+0j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  10 cluster of 2   Clicks are  01
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.013219312514472906+0j)
# Worst case is : 011001010 value: (0.013219312514472923+0j)
# Best case is : 000000100 value: (0.0132193125144729+0j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  2 cluster of 2   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.15796903255164255+0j)
# Worst case is : 0 value: (0.15796903255164255+0j)
# Best case is : 0 value: (0.15796903255164255+0j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  3 cluster of 2   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.2113821567976529+0j)
# Worst case is : 00 value: (0.2113821567976529+0j)
# Best case is : 01 value: (0.07081307299643926+0j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  4 cluster of 2   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.2192847441156359+0j)
# Worst case is : 000 value: (0.2192847441156359+0j)
# Best case is : 010 value: (0.09335223976022729+0j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  5 cluster of 2   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.20390579108117876+0j)
# Worst case is : 0000 value: (0.20390579108117876+0j)
# Best case is : 0011 value: (0.050009595906604025+0j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  6 cluster of 2   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.17828395583710802+0j)
# Worst case is : 00000 value: (0.17828395583710802+0j)
# Best case is : 00111 value: (0.052863766435158166+0j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  7 cluster of 2   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.1498111224314413+0j)
# Worst case is : 000000 value: (0.1498111224314413+0j)
# Best case is : 011100 value: (0.030586116481532484+0j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  8 cluster of 2   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.12242272044066133+0j)
# Worst case is : 0000000 value: (0.12242272044066133+0j)
# Best case is : 0011001 value: (0.02918649911085428+0j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  9 cluster of 2   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# Naive (00..0) dist from ideal : (0.09798580969836924+0j)
# Worst case is : 00000000 value: (0.09798580969836924+0j)
# Best case is : 01000111 value: (0.01763678931147022+0j)
# ---------------------------------------
# ---------------------------------------
# Finding combination for  10 cluster of 2   Clicks are  00
# State change from cluster is theta= 0
# Statrting...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [8], line 3
#       1 # Function of size?
#       2 for i in range(1,10,1):
# ----> 3     runOverPMCombinations(fi, fp, fm, cluster_size=2, clicks='00', fusions_amount=i)
#
# File C:\PycharmProjects\LOQCGateSimulation\main.py:30, in runOverPMCombinations(fi, fp, fm, cluster_size, clicks, fusions_amount, rot_state_angle, rot_state_axis)
#      28     else:
#      29         fusions_list += [fm]
# ---> 30 c12pm = Cluster.fuseLinearClusters(size_of_cluster=cluster_size, clicks=clicks, fusions=fusions_list, rot_state_angle=rot_state_angle, rot_state_axis=rot_state_axis)
#      31 # print("for: "+str(b)+" PM dist from ideal : " + str(c12pm - c12i))
#      32 if c12pm - c12i > worst_case:
#
# File C:\PycharmProjects\LOQCGateSimulation\Cluster.py:144, in Cluster.fuseLinearClusters(size_of_cluster, clicks, fusions, rot_state_angle, rot_state_axis)
#     142     other_cluster = Cluster(size_of_cluster)
#     143     other_cluster.rotate(1, rot_state_angle, rot_state_axis)
# --> 144     c_out = c_out.fusion(other=Cluster(size_of_cluster),
#     145                          fusion_gate=fusions[i - 1], clicks=clicks)
#     146 return c_out
#
# File C:\PycharmProjects\LOQCGateSimulation\Cluster.py:122, in Cluster.fusion(self, other, fusion_gate, clicks)
#     120     original_u = np.kron(self.U, other.U)
#     121     mid_u = np.kron(np.kron(np.eye(int(len(self.q_state)*0.5)), ZZ), np.eye(int(len(other.q_state)*0.5)))
# --> 122     new_U = np.matmul(mid_u, original_u)
#     124 return Cluster(new_c_q_state, new_U)
#
# KeyboardInterrupt:
